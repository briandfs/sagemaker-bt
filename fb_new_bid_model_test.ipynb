# %%
import boto3
import datetime as dt
import pytz
import time
import uuid
import json
import s3fs
from urllib.parse import urlparse
import pandas as pd
import requests
import numpy as np
from decimal import *
from io import StringIO
import numpy as np

# %%
df = pd.read_csv('s3://fb-beeswax/brian/ml-prediction/2019-02-22/fb-prediction-2019-02-22-230548.csv')

# %%
df.head()
# Out:
#    conversions  campaign_id  impressions  clicks                   app_bundle  \
# 0            0            6            1       0  com.enflick.android.TextNow
# 1            0            6            2       0             com.myyearbook.m
# 2            0            6            1       0   com.mobilityware.solitaire
# 3            0            6            1       0             com.imgur.mobile
# 4            0            6            3       0  com.enflick.android.TextNow
#
#         ad_position geo_region geo_country platform_browser platform_os  \
# 0               NaN     USA/CA         USA    Chrome Mobile     Android
# 1  POSITION_UNKNOWN     USA/WA         USA    Chrome Mobile     Android
# 2  POSITION_UNKNOWN     USA/PA         USA    Chrome Mobile     Android
# 3  POSITION_UNKNOWN     USA/NV         USA    Chrome Mobile     Android
# 4               NaN     USA/NY         USA    Chrome Mobile     Android
#
#      ...     video_completes content_language companion_views  \
# 0    ...                   0              NaN               0
# 1    ...                   1               en               0
# 2    ...                   0               EN               0
# 3    ...                   0               EN               0
# 4    ...                   1              NaN               0
#
#   companion_clicks banner_width  banner_height inventory_source  \
# 0                0           -1             -1        STICKYADS
# 1                0           -1             -1          RUBICON
# 2                0           -1             -1          RUBICON
# 3                0           -1             -1          RUBICON
# 4                0           -1             -1        STICKYADS
#
#    inventory_interstitial     spend     score
# 0                       0  0.003762  0.000048
# 1                       0  0.007294  0.916711
# 2                       0  0.003799  0.000023
# 3                       0  0.003262  0.002104
# 4                       0  0.011397  0.004883
#
# [5 rows x 25 columns]

# %%
len(df)
# Out:
# 1292686
