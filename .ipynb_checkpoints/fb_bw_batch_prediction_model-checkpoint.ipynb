# %%
import boto3
import datetime as dt
import pytz
import time
import uuid
import json
import s3fs
from urllib.parse import urlparse
import pandas as pd
import requests
import numpy as np
from decimal import *
from io import StringIO
import numpy as np

# %%
cookies = {
}

data = '{"email":"btomasette@camelotsmm.com", "password":"Dunmore1"}'

auth = 'https://facebook.api.beeswax.com/rest/authenticate'

get_advertisers = 'https://facebook.api.beeswax.com/rest/advertiser'

save_report = 'https://facebook.api.beeswax.com/rest/report_save'

report_queue = 'https://facebook.api.beeswax.com/rest/report_queue'

list_item_bulk = 'https://facebook.api.beeswax.com/rest/list_item_bulk'

get_lists = 'https://facebook.api.beeswax.com/rest/custom_list'

bid_model_version = 'https://facebook.api.beeswax.com/rest/bid_model_version'

update_active_model_version = 'https://facebook.api.beeswax.com/rest/bid_model/strict/1' 

r = requests.post(auth, cookies=cookies, data=data)

tz = pytz.timezone('EST')

today = dt.datetime.now(tz)
sevenday = today - dt.timedelta(days=7)

# %%
# query athena view of impression, click, and joined conversion data for tag_id 3
query = """
SELECT  conversions,
         campaign_id,
         impressions,
         clicks,
         app_bundle,
         ad_position,
         geo_region,
         geo_country,
         platform_browser,
         platform_os,
         rewarded,
         platform_carrier,
         platform_device_make,
         platform_device_model,
         video_player_size,
         video_completes,
         content_language,
         companion_views,
         companion_clicks,
         banner_width,
         banner_height,
         inventory_source,
         inventory_interstitial,
         spend
FROM "fb-prod"."fbbatchprediction" 
"""

# %%
# set database to facebook
database = 'fb-prod'
#set s3 output file for athena query
s3_output = 's3://fb-beeswax/brian/athena/%s/'%(dt.datetime.now(tz).strftime('%Y-%m-%d-%H%M%S'))

#Function for starting athena query
def run_query(query, database, s3_output):
    client = boto3.client('athena', region_name='us-east-1')
    response = client.start_query_execution(
        QueryString=query,
        QueryExecutionContext={
            'Database': database
            },
        ResultConfiguration={
            'OutputLocation': s3_output,
            }
        )
    print('Execution ID: ' + response['QueryExecutionId'])
    return response

#run athena query and kick back job id
job = run_query(query, database, s3_output)

job_id = job['QueryExecutionId']
client = boto3.client('athena', region_name='us-east-1')
res = client.get_query_execution(QueryExecutionId= job_id)
x = 0

# wait for athena to return results
while res['QueryExecution']['Status']['State'] != 'SUCCEEDED':
    print("it's been {} seconds".format(str(x)))
    time.sleep(10)
    x = x + 10
    res = client.get_query_execution(QueryExecutionId= job_id)

#set output location for query results
output = res['QueryExecution']['ResultConfiguration']['OutputLocation']
# Out:
# Execution ID: 7e95d890-7a37-4daa-8f58-b473c7c992fb
# it's been 0 seconds
# it's been 10 seconds
# it's been 20 seconds
# it's been 30 seconds

# %%
#set aws machine learning client and build schema for datasource
mlclient = boto3.client('machinelearning', region_name='us-east-1')

data_id = str(uuid.uuid4())
data_name = 'fb-datasource-%s'%(dt.datetime.now(tz).strftime('%Y-%m-%d-%H%M%S'))

schema = {
        'excludedAttributeNames': [], 
        'version': '1.0', 
        'dataFormat': 'CSV', 
        'rowId': None, 
        'dataFileContainsHeader': True, 
        'attributes': [
            {
                'attributeName': 'conversions', 
                'attributeType': 'BINARY'
            }, {
                'attributeName' : 'campaign_id',
                'attributeType' : 'CATEGORICAL'
            }, {
                'attributeName': 'impressions', 
                'attributeType': 'NUMERIC'
            }, {
                'attributeName': 'clicks', 
                'attributeType': 'NUMERIC'
            }, {
                'attributeName': 'app_bundle', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'ad_position', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'geo_region', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'geo_country', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'platform_browser', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'platform_os', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'rewarded', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'platform_carrier', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'platform_device_make', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'platform_device_model', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'video_player_size', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'video_completes', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'content_language', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'companion_views', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'companion_clicks', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'banner_width', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'banner_height', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'inventory_source',
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'inventory_interstitial',
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'spend',
                'attributeType': 'NUMERIC'
            }
        ]
    }


# load new datasource into aws machine learning
response = mlclient.create_data_source_from_s3(DataSourceId=data_id, DataSourceName=data_name, DataSpec={"DataLocationS3" : output, "DataSchema" : json.dumps(schema)}, ComputeStatistics=True)

# %%
#build new batch prediction and set output file in S3
prediction_id = str(uuid.uuid4())
prediction_name = 'fb-prediction-%s'%(dt.datetime.now(tz).strftime('%Y-%m-%d-%H%M%S'))
prediction_output = 's3://fb-beeswax/brian/ml/%s/'%(dt.datetime.now(tz).strftime('%Y-%m-%d-%H%M%S'))
prediction_data_source_id = response['DataSourceId']
pred = mlclient.create_batch_prediction(BatchPredictionId=prediction_id, BatchPredictionName=prediction_name, MLModelId='fd8e2261-bc58-4e6a-a1af-5846c60d5df7', BatchPredictionDataSourceId=prediction_data_source_id , OutputUri=prediction_output)

get_pred = mlclient.get_batch_prediction(BatchPredictionId=pred['BatchPredictionId'])
gpt = 0
while get_pred['Status'] != 'COMPLETED':
    time.sleep(30)
    gpt = gpt + 30
    print("batch prediction processing for %s seconds" %gpt)
    get_pred = mlclient.get_batch_prediction(BatchPredictionId=pred['BatchPredictionId'])
# Out:
# batch prediction processing for 30 seconds
# batch prediction processing for 60 seconds
# batch prediction processing for 90 seconds
# batch prediction processing for 120 seconds
# batch prediction processing for 150 seconds
# batch prediction processing for 180 seconds
# batch prediction processing for 210 seconds
# batch prediction processing for 240 seconds
# batch prediction processing for 270 seconds

# %%
#load original athena result into a dataframe
df = pd.read_csv(output)

#build score output url
o = urlparse(output)
score = get_pred['OutputUri'] + 'batch-prediction/result/' + get_pred['BatchPredictionId'] + '-' + o[2].split('/')[4].split('.')[0] + '.csv.gz'

#load score into a dataframe
ds = pd.read_csv(score, compression='gzip')

df['score'] = ds['score']

# %%
#calculate range of scores
#range = df['score'].max() - df['score'].min()

#zero out any items below 0.009

#df['bid_mod'] = df['score'].apply(lambda y : 0 if y < 0.01 else y)

s3 = boto3.client(
    's3', region_name='us-east-1')
csv_buffer = StringIO()
df.to_csv(csv_buffer, index=False)
res = s3.put_object(Body = csv_buffer.getvalue(),
                               ContentType='text/csv',
                               Bucket='fb-beeswax',
                               Key = 'brian/ml-prediction/{}/{}.csv'.format(dt.datetime.now(tz).strftime('%Y-%m-%d'), prediction_name ))

# %%
ds.head()
# Out:
#    bestAnswer     score
# 0           0  0.001229
# 1           0  0.140469
# 2           0  0.006262
# 3           1  0.599698
# 4           0  0.089990

# %%
df.head()
# Out:
#    conversions  campaign_id  impressions  clicks                   app_bundle  \
# 0            0            6            1       0   com.scopely.wheeloffortune
# 1            0            6            1       0  com.enflick.android.TextNow
# 2            0            6            1       0             com.myyearbook.m
# 3            0            6            3       0                 com.thechive
# 4            0            6            2       0                 com.thechive
#
#         ad_position geo_region geo_country platform_browser platform_os  \
# 0  POSITION_UNKNOWN     USA/NY         USA    Chrome Mobile     Android
# 1               NaN     USA/ID         USA    Chrome Mobile     Android
# 2  POSITION_UNKNOWN     USA/TX         USA    Chrome Mobile     Android
# 3               NaN     USA/OR         USA    Chrome Mobile     Android
# 4               NaN     USA/MD         USA    Chrome Mobile     Android
#
#      ...     content_language time_of_week companion_views companion_clicks  \
# 0    ...                   EN         2461               0                0
# 1    ...                  NaN         2462               0                0
# 2    ...                   en         2462               0                0
# 3    ...                  NaN         2471               0                0
# 4    ...                  NaN         2474               0                0
#
#   banner_width  banner_height inventory_source  inventory_interstitial  \
# 0           -1             -1          RUBICON                       0
# 1           -1             -1        STICKYADS                       0
# 2           -1             -1          RUBICON                       0
# 3           -1             -1        STICKYADS                       0
# 4           -1             -1        STICKYADS                       0
#
#       spend     score
# 0  0.003799  0.001229
# 1  0.003799  0.140469
# 2  0.003799  0.006262
# 3  0.011031  0.599698
# 4  0.007354  0.089990
#
# [5 rows x 26 columns]

# %%
dz = df.drop(['conversions', 'video_completes', 'impressions', 'clicks', 'companion_views', 'companion_clicks', 'spend', 'time_of_week'], axis=1)

# %%
cols = ['banner_width', 'banner_height', 'rewarded']
for col in cols:
   dz[col] = df[col].apply(lambda x: int(x) if x == x else "")

# %%
dz.head(16)
# Out:
#     campaign_id                           app_bundle       ad_position  \
# 0             6           com.scopely.wheeloffortune  POSITION_UNKNOWN
# 1             6          com.enflick.android.TextNow               NaN
# 2             6                     com.myyearbook.m  POSITION_UNKNOWN
# 3             6                         com.thechive               NaN
# 4             6                         com.thechive               NaN
# 5             6          com.enflick.android.TextNow               NaN
# 6             6                com.naver.linewebtoon               NaN
# 7             6                  com.weather.Weather  POSITION_UNKNOWN
# 8             6         com.easybrain.sudoku.android  POSITION_UNKNOWN
# 9             6          com.enflick.android.TextNow               NaN
# 10            6                com.naver.linewebtoon  POSITION_UNKNOWN
# 11            6          com.enflick.android.TextNow               NaN
# 12            6                    bubbles.pop.power  POSITION_UNKNOWN
# 13            6           com.scopely.wheeloffortune  POSITION_UNKNOWN
# 14            6                 com.podcast.podcasts  POSITION_UNKNOWN
# 15            6  com.pixel.art.coloring.color.number    ABOVE_THE_FOLD
#
#    geo_region geo_country platform_browser platform_os  rewarded  \
# 0      USA/NY         USA    Chrome Mobile     Android        -1
# 1      USA/ID         USA    Chrome Mobile     Android        -1
# 2      USA/TX         USA    Chrome Mobile     Android        -1
# 3      USA/OR         USA    Chrome Mobile     Android        -1
# 4      USA/MD         USA    Chrome Mobile     Android        -1
# 5      USA/NC         USA    Chrome Mobile     Android        -1
# 6      USA/NV         USA    Chrome Mobile     Android        -1
# 7      USA/CT         USA    Chrome Mobile     Android        -1
# 8      USA/NY         USA    Chrome Mobile     Android        -1
# 9      USA/NY         USA    Chrome Mobile     Android        -1
# 10     USA/FL         USA    Chrome Mobile     Android        -1
# 11     USA/CA         USA    Chrome Mobile     Android        -1
# 12     USA/UT         USA    Chrome Mobile     Android        -1
# 13     USA/OH         USA    Chrome Mobile     Android        -1
# 14     USA/NY         USA    Chrome Mobile     Android        -1
# 15     USA/NJ         USA    Chrome Mobile     Android        -1
#
#    platform_carrier platform_device_make platform_device_model  \
# 0          T-Mobile                   LG            LM-X210(G)
# 1               NaN              Samsung             SM-S327VL
# 2              AT&T              Samsung             SM-J327AZ
# 3               NaN              Samsung              SM-G950U
# 4               NaN              Samsung              SM-G950U
# 5               NaN                  ZTE                 N9560
# 6               NaN                  TCL                 5059R
# 7               NaN              Samsung              SM-G955U
# 8               NaN               Google                 Pixel
# 9               NaN             Motorola               Moto G6
# 10              NaN                  TCL                A574BL
# 11              NaN             Motorola                XT1766
# 12         T-Mobile              Samsung              SM-G955U
# 13          Verizon              Samsung              SM-J327V
# 14              NaN              Samsung              SM-J320V
# 15              NaN              Samsung              SM-N950U
#
#    video_player_size content_language  banner_width  banner_height  \
# 0                  L               EN            -1             -1
# 1                  L              NaN            -1             -1
# 2                  S               en            -1             -1
# 3                  M              NaN            -1             -1
# 4                  M              NaN            -1             -1
# 5                  M              NaN            -1             -1
# 6                  M              NaN            -1             -1
# 7                  M              NaN            -1             -1
# 8                  S               en            -1             -1
# 9                  L              NaN            -1             -1
# 10                 L               EN            -1             -1
# 11                 L              NaN            -1             -1
# 12                 L               EN            -1             -1
# 13                 L               EN            -1             -1
# 14                 S              NaN           300            250
# 15                 M               EN            -1             -1
#
#    inventory_source  inventory_interstitial     value
# 0           RUBICON                       0  0.001229
# 1         STICKYADS                       0  0.140469
# 2           RUBICON                       0  0.006262
# 3         STICKYADS                       0  0.599698
# 4         STICKYADS                       0  0.089990
# 5         STICKYADS                       0  0.272823
# 6            TREMOR                       1  0.286348
# 7           RUBICON                       0  0.743727
# 8           RUBICON                       0  0.015747
# 9         STICKYADS                       0  0.338810
# 10          RUBICON                       0  0.078096
# 11        STICKYADS                       0  0.130426
# 12          RUBICON                       0  0.000366
# 13          RUBICON                       0  0.000410
# 14       MILLENNIAL                       0  0.009034
# 15          RUBICON                       0  0.001296

# %%
dz.rename(columns={'score':'value'}, inplace=True)

# %%
dz.replace(-1, "", inplace=True)

# %%
dz.replace({'ad_position' : {'0' : np.nan}}, inplace=True)

# %%
dz.head()
# Out:
#    campaign_id                   app_bundle       ad_position geo_region  \
# 0            6   com.scopely.wheeloffortune  POSITION_UNKNOWN     USA/NY
# 1            6  com.enflick.android.TextNow               NaN     USA/ID
# 2            6             com.myyearbook.m  POSITION_UNKNOWN     USA/TX
# 3            6                 com.thechive               NaN     USA/OR
# 4            6                 com.thechive               NaN     USA/MD
#
#   geo_country platform_browser platform_os rewarded platform_carrier  \
# 0         USA    Chrome Mobile     Android                  T-Mobile
# 1         USA    Chrome Mobile     Android                       NaN
# 2         USA    Chrome Mobile     Android                      AT&T
# 3         USA    Chrome Mobile     Android                       NaN
# 4         USA    Chrome Mobile     Android                       NaN
#
#   platform_device_make platform_device_model video_player_size  \
# 0                   LG            LM-X210(G)                 L
# 1              Samsung             SM-S327VL                 L
# 2              Samsung             SM-J327AZ                 S
# 3              Samsung              SM-G950U                 M
# 4              Samsung              SM-G950U                 M
#
#   content_language banner_width banner_height inventory_source  \
# 0               EN                                     RUBICON
# 1              NaN                                   STICKYADS
# 2               en                                     RUBICON
# 3              NaN                                   STICKYADS
# 4              NaN                                   STICKYADS
#
#    inventory_interstitial     value
# 0                       0  0.001229
# 1                       0  0.140469
# 2                       0  0.006262
# 3                       0  0.599698
# 4                       0  0.089990

# %%
file_size = dz.memory_usage(index=True).sum()
partitions = round(file_size/1024/1024/10)

# %%
s3 = boto3.client(
    's3', aws_access_key_id='AKIAJKXTYAFKSXDNEWKQ',
    aws_secret_access_key='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', region_name='us-east-1')
s3resource = boto3.resource('s3', aws_access_key_id='AKIAJKXTYAFKSXDNEWKQ',
    aws_secret_access_key='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', region_name='us-east-1')

# %%
number_of_chunks = partitions
s3_array = []
for id, dz_i in  enumerate(np.array_split(dz, number_of_chunks)):
    csv_buffer = StringIO()
    dz_i.to_csv(csv_buffer, sep='|', index=False)
    bucket = 'beeswax-data-us-east-1'
    prefix = 'bid_models/facebook/predictions/'
    key = '{}_{}_file{id}.csv'.format(dt.datetime.now(tz).strftime('%Y-%m-%d'), prediction_name, id=id )
    res = s3.put_object(Body = csv_buffer.getvalue(),
                               ContentType='text/csv',
                               Bucket= bucket,
                               Key = prefix + key)
    s3resource.Object(bucket, prefix+key).Acl().put(ACL='bucket-owner-full-control')
    s3_array.append('s3://{}/{}{}'.format(bucket, prefix, key))

# %%
s3_array
# Out:
# ['s3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file0.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file1.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file2.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file3.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file4.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file5.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file6.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file7.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file8.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file9.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file10.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file11.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file12.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file13.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file14.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file15.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file16.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file17.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file18.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file19.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file20.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file21.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file22.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file23.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file24.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file25.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file26.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file27.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file28.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file29.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file30.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file31.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file32.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file33.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file34.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file35.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file36.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file37.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file38.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file39.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file40.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file41.csv']

# %%
print(key)
print(prefix+key)
print(res)
# Out:
# 2019-02-21_fb-prediction-2019-02-21-172640_file41.csv
# bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file41.csv
# {'ResponseMetadata': {'RequestId': 'F2BD2F4B3A497F48', 'HostId': 'OycgAmj65HjZFWu5MnkMWDrhxMNdGWBI8PCv2bZkFJuti8Atk+QIhmiEwcKu96jrR5oanGXiwJk=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'OycgAmj65HjZFWu5MnkMWDrhxMNdGWBI8PCv2bZkFJuti8Atk+QIhmiEwcKu96jrR5oanGXiwJk=', 'x-amz-request-id': 'F2BD2F4B3A497F48', 'date': 'Fri, 22 Feb 2019 03:41:21 GMT', 'x-amz-version-id': 'iCR65fvnAU8fZBXLZiRYeKb7QNYVJzKb', 'etag': '"1c181446e950f4601729d483f2b89455"', 'content-length': '0', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ETag': '"1c181446e950f4601729d483f2b89455"', 'VersionId': 'iCR65fvnAU8fZBXLZiRYeKb7QNYVJzKb'}

# %%
dmanifest = dz.drop(['value'], axis=1)

# %%
manifest = {
    'model_predictions' : 
        s3_array
    ,
    'metadata' : {
        'fields' : dmanifest.columns.tolist()
    }
}

# %%
print(manifest)
# Out:
# {'model_predictions': ['s3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file0.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file1.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file2.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file3.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file4.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file5.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file6.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file7.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file8.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file9.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file10.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file11.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file12.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file13.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file14.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file15.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file16.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file17.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file18.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file19.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file20.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file21.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file22.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file23.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file24.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file25.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file26.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file27.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file28.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file29.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file30.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file31.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file32.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-21_fb-prediction-2019-02-21-172640_file33.csv', 's3://bee ...

# %%
obj_manifest = s3resource.Object(bucket,'bid_models/facebook/customer_manifests/manifest_{}.json'.format(key))
obj_manifest.put(Body=json.dumps(manifest))
obj_manifest.Acl().put(ACL='bucket-owner-full-control')
# Out:
# {'ResponseMetadata': {'RequestId': 'FAD6695545AFFD11',
#   'HostId': 'UgCRJeuurrS+/KmHKUHgJaaqv9bz/jIY9dDl7+UXFGKxHq2MYjreMl5YEqm4U3XslAN2KDfbpYc=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'UgCRJeuurrS+/KmHKUHgJaaqv9bz/jIY9dDl7+UXFGKxHq2MYjreMl5YEqm4U3XslAN2KDfbpYc=',
#    'x-amz-request-id': 'FAD6695545AFFD11',
#    'date': 'Fri, 22 Feb 2019 03:42:23 GMT',
#    'x-amz-version-id': '4sTh1Ko.J3rNjcjgvGJ4VH6pxDVGjjGP',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0}}

# %%
manifest_path = 's3://{}/{}'.format(bucket, 'bid_models/facebook/customer_manifests/manifest_{}.json'.format(key))

# %%
manifest_path
# Out:
# 's3://beeswax-data-us-east-1/bid_models/facebook/customer_manifests/manifest_2019-02-21_fb-prediction-2019-02-21-172640_file41.csv.json'

# %%
model = {
    "active" : True,
    "bid_model_id" : 1,
    "bid_model_version_name" : '{}_{}'.format(dt.datetime.now(tz).strftime('%Y-%m-%d-%H%M%S'), prediction_name ),
    "manifest_s3_path" : manifest_path
}

# %%
model
# Out:
# {'active': True,
#  'bid_model_id': 1,
#  'bid_model_version_name': '2019-02-21-224227_fb-prediction-2019-02-21-172640',
#  'manifest_s3_path': 's3://beeswax-data-us-east-1/bid_models/facebook/customer_manifests/manifest_2019-02-21_fb-prediction-2019-02-21-172640_file41.csv.json'}

# %%
upload_model = requests.post(bid_model_version, cookies=r.cookies, data=json.dumps(model))

# %%
upload_model.json()
# Out:
# {'success': True,
#  'payload': {'id': 9},
#  'message': 'bid_model_version created with ID = 9'}

# %%
model_version_data = {
    "bid_model_id" : 1,
    "active" : True,
    "current_version" : upload_model.json()['payload']['id']
}

# %%
update_version = requests.put(update_active_model_version, cookies=r.cookies, data=json.dumps(model_version_data))

# %%
update_version.json()
# Out:
# {'success': True,
#  'payload': [{'id': 1,
#    'success': True,
#    'message': 'bid_model updated with ID 1'}],
#  'message': 'bid_model update: 1 updated successfully'}

# %%
df.sort_values(by=['impressions', ''], ascending=False)
# Out:
#          conversions  campaign_id  impressions  clicks  \
# 128836             0            6           73       0
# 684424             0            6           58       0
# 730928             0            6           55       0
# 430258             0            6           52       0
# 210806             0            6           45       0
# 52807              0            6           45       1
# 966954             0            6           42       0
# 205230             0            6           41       0
# 10773              0            6           39       0
# 236123             0            6           39       0
# 180741             0            6           39       0
# 1037096            0            6           38       0
# 20392              0            6           38       0
# 48081              0            6           38       0
# 265941             0            6           37       0
# 22575              0            6           37       0
# 121866             0            6           37       0
# 658156             0            6           37       0
# 735232             0            6           37       0
# 182478             0            6           37       0
# 96144              0            6           37       0
# 201842             0            6           37       0
# 359047             0            6           36       0
# 587928             0            6           36       0
# 901360             0            6           36       0
# 776546             0            6           36       0
# 902741             0            6           36       0
# 390130             0            6           36       0
# 180035             0            6           36       0
# 595917             0            6           36       0
# ...              ...          ...          ...     ...
# 1352064            0            6            1       0
# 1352065            0            6            1       0
# 1352066            0            6            1       0
# 1352068            0            6            1       0
# 1352058            0            6            1       0
# 1352069            0            6            1       0
# 1352070            0            6            1       0
# 1352071            0            6            1       0
# 1352072            0            6            1       0
# 1352073            0            6            1       0
# 1352075            0            6            1       0
# 1352059            0            6            1       0
# 1352057            0            6            1       0
# 1352040            0            6            1       0
# 1352048            0            6            1       0
# 1352041            0            6            1       0
# 1352042            0            6            1       0
# 1352043            0            6            1       0
# 1352045            0            6            1       0
# 1352046            0            6            1       0
# 1352047            0            6            1       0
# 1352049            0            6            1       0
# 1352056            0            6            1       0
# 1352050            0            6            1       0
# 1352051            0            6            1       0
# 1352052            0            6            1       0
# 1352053            0            6            1       0
# 1352054            0            6            1       0
# 1352055            0            6            1       0
# 3063286            0            6            1       0
#
#                               app_bundle       ad_position geo_region  \
# 128836                           UNKNOWN                 0     000/00
# 684424       com.enflick.android.TextNow               NaN     USA/TX
# 730928       com.enflick.android.TextNow               NaN     USA/FL
# 430258       com.enflick.android.TextNow               NaN     USA/FL
# 210806                           UNKNOWN                 0     000/00
# 52807                            UNKNOWN                 0     000/00
# 966954        com.scopely.wheeloffortune               NaN     USA/TX
# 205230        com.scopely.wheeloffortune               NaN     USA/MA
# 10773         com.scopely.wheeloffortune               NaN     USA/KY
# 236123        com.scopely.wheeloffortune               NaN     USA/FL
# 180741        com.scopely.wheeloffortune               NaN     USA/MI
# 1037096       com.scopely.wheeloffortune               NaN     USA/TX
# 20392         com.scopely.wheeloffortune               NaN     USA/IL
# 48081         com.scopely.wheeloffortune               NaN     USA/MO
# 265941        com.scopely.wheeloffortune               NaN     USA/TX
# 22575         com.scopely.wheeloffortune               NaN     USA/NJ
# 121866        com.scopely.wheeloffortune               NaN     USA/MD
# 658156        com.scopely.wheeloffortune               NaN     USA/WA
# 735232                   com.aws.android  POSITION_UNKNOWN     USA/FL
# 182478        com.scopely.wheeloffortune               NaN     USA/NC
# 96144         com.scopely.wheeloffortune               NaN     USA/NM
# 201842        com.scopely.wheeloffortune               NaN     USA/NY
# 359047        com.scopely.wheeloffortune               NaN     USA/TN
# 587928        com.scopely.wheeloffortune               NaN     USA/GA
# 901360        com.scopely.wheeloffortune               NaN     USA/TX
# 776546        com.scopely.wheeloffortune               NaN     USA/KS
# 902741        com.scopely.wheeloffortune               NaN     USA/CO
# 390130        com.scopely.wheeloffortune               NaN     USA/MD
# 180035        com.scopely.wheeloffortune               NaN     USA/IL
# 595917        com.scopely.wheeloffortune               NaN     USA/WI
# ...                                  ...               ...        ...
# 1352064          com.tripledot.solitaire    ABOVE_THE_FOLD     USA/MI
# 1352065                 com.imgur.mobile  POSITION_UNKNOWN     USA/IL
# 1352066       com.mobilityware.solitaire  POSITION_UNKNOWN     USA/MO
# 1352068       com.mobilityware.solitaire  POSITION_UNKNOWN     USA/WA
# 1352058                 com.imgur.mobile  POSITION_UNKNOWN     USA/CT
# 1352069       com.mobilityware.solitaire  POSITION_UNKNOWN     USA/CA
# 1352070  com.zynga.crosswordswithfriends               NaN     USA/FL
# 1352071         com.peoplefun.wordstacks  POSITION_UNKNOWN     USA/TX
# 1352072                     com.thechive               NaN     USA/TX
# 1352073            com.naver.linewebtoon  POSITION_UNKNOWN     USA/MI
# 1352075      com.enflick.android.TextNow               NaN     USA/MO
# 1352059      com.enflick.android.TextNow               NaN     USA/MO
# 1352057      com.enflick.android.TextNow               NaN     USA/NE
# 1352040             com.podcast.podcasts               NaN     USA/CA
# 1352048                     com.thechive               NaN     USA/SD
# 1352041      com.enflick.android.TextNow               NaN     USA/PA
# 1352042      com.enflick.android.TextNow  POSITION_UNKNOWN     USA/AL
# 1352043  com.etermax.trivia.preguntados2  POSITION_UNKNOWN     USA/CA
# 1352045       com.scopely.wheeloffortune  POSITION_UNKNOWN     USA/PA
# 1352046             com.podcast.podcasts               NaN     USA/VA
# 1352047             com.podcast.podcasts               NaN     USA/GA
# 1352049      com.enflick.android.TextNow               NaN     USA/FL
# 1352056      com.europosit.pixelcoloring  POSITION_UNKNOWN     USA/NJ
# 1352050             com.podcast.podcasts               NaN     USA/NJ
# 1352051            com.naver.linewebtoon  POSITION_UNKNOWN     USA/NY
# 1352052                       wp.wattpad  POSITION_UNKNOWN         NE
# 1352053                  com.zynga.words  POSITION_UNKNOWN     USA/FL
# 1352054      com.europosit.pixelcoloring  POSITION_UNKNOWN     USA/TN
# 1352055             com.podcast.podcasts               NaN     USA/MD
# 3063286             com.podcast.podcasts               NaN     USA/MI
#
#         geo_country platform_browser platform_os    ...     content_language  \
# 128836          000          UNKNOWN          -1    ...                   -1
# 684424          USA    Chrome Mobile     Android    ...                  NaN
# 730928          USA    Chrome Mobile     Android    ...                  NaN
# 430258          USA    Chrome Mobile     Android    ...                  NaN
# 210806          000          UNKNOWN          -1    ...                   -1
# 52807           000          UNKNOWN          -1    ...                   -1
# 966954          USA    Chrome Mobile     Android    ...                  NaN
# 205230          USA    Chrome Mobile     Android    ...                  NaN
# 10773           USA    Chrome Mobile     Android    ...                  NaN
# 236123          USA    Chrome Mobile     Android    ...                  NaN
# 180741          USA    Chrome Mobile     Android    ...                  NaN
# 1037096         USA    Chrome Mobile     Android    ...                  NaN
# 20392           USA    Chrome Mobile     Android    ...                  NaN
# 48081           USA    Chrome Mobile     Android    ...                  NaN
# 265941          USA    Chrome Mobile     Android    ...                  NaN
# 22575           USA    Chrome Mobile     Android    ...                  NaN
# 121866          USA    Chrome Mobile     Android    ...                  NaN
# 658156          USA    Chrome Mobile     Android    ...                  NaN
# 735232          USA    Chrome Mobile     Android    ...                   en
# 182478          USA    Chrome Mobile     Android    ...                  NaN
# 96144           USA    Chrome Mobile     Android    ...                  NaN
# 201842          USA    Chrome Mobile     Android    ...                  NaN
# 359047          USA    Chrome Mobile     Android    ...                  NaN
# 587928          USA    Chrome Mobile     Android    ...                  NaN
# 901360          USA    Chrome Mobile     Android    ...                  NaN
# 776546          USA    Chrome Mobile     Android    ...                  NaN
# 902741          USA    Chrome Mobile     Android    ...                  NaN
# 390130          USA    Chrome Mobile     Android    ...                  NaN
# 180035          USA    Chrome Mobile     Android    ...                  NaN
# 595917          USA    Chrome Mobile     Android    ...                  NaN
# ...             ...              ...         ...    ...                  ...
# 1352064         USA    Chrome Mobile     Android    ...                  NaN
# 1352065         USA    Chrome Mobile     Android    ...                  NaN
# 1352066         USA    Chrome Mobile     Android    ...                  NaN
# 1352068         USA    Chrome Mobile     Android    ...                   en
# 1352058         USA    Chrome Mobile     Android    ...                   EN
# 1352069         USA    Chrome Mobile     Android    ...                  NaN
# 1352070         USA    Chrome Mobile     Android    ...                  NaN
# 1352071         USA    Chrome Mobile     Android    ...                  NaN
# 1352072         USA    Chrome Mobile     Android    ...                  NaN
# 1352073         USA    Chrome Mobile     Android    ...                   EN
# 1352075         USA    Chrome Mobile     Android    ...                  NaN
# 1352059         USA    Chrome Mobile     Android    ...                  NaN
# 1352057         USA    Chrome Mobile     Android    ...                  NaN
# 1352040         USA    Chrome Mobile     Android    ...                  NaN
# 1352048         USA    Chrome Mobile     Android    ...                  NaN
# 1352041         USA    Chrome Mobile     Android    ...                  NaN
# 1352042         USA    Chrome Mobile     Android    ...                  NaN
# 1352043         USA    Chrome Mobile     Android    ...                  NaN
# 1352045         USA    Chrome Mobile     Android    ...                   en
# 1352046         USA    Chrome Mobile     Android    ...                  NaN
# 1352047         USA    Chrome Mobile     Android    ...                  NaN
# 1352049         USA    Chrome Mobile     Android    ...                  NaN
# 1352056         USA    Chrome Mobile     Android    ...                  NaN
# 1352050         USA    Chrome Mobile     Android    ...                  NaN
# 1352051         USA    Chrome Mobile     Android    ...                   EN
# 1352052         USA    Chrome Mobile     Android    ...                   EN
# 1352053         USA    Chrome Mobile     Android    ...                  NaN
# 1352054         USA    Chrome Mobile     Android    ...                  NaN
# 1352055         USA    Chrome Mobile     Android    ...                  NaN
# 3063286         USA    Chrome Mobile     Android    ...                  NaN
#
#         time_of_week companion_views companion_clicks banner_width  \
# 128836            -1               0                0           -1
# 684424          3183               0                0           -1
# 730928          3181               0                0           -1
# 430258          3182               0                0           -1
# 210806            -1               1                0           -1
# 52807             -1               0                0           -1
# 966954          3117               0                0           -1
# 205230          2513               0                0           -1
# 10773           2304               0                0           -1
# 236123          2428               0                0           -1
# 180741          1484               0                0           -1
# 1037096         2528               0                0           -1
# 20392           1459               0                0           -1
# 48081           2473               0                0           -1
# 265941          2435               0                0           -1
# 22575           2508               0                0           -1
# 121866          2345               0                0           -1
# 658156          2806               0                0           -1
# 735232          2340               0                0           -1
# 182478          1462               0                0           -1
# 96144           1490               0                0           -1
# 201842          2522               0                0           -1
# 359047          2641               0                0           -1
# 587928          2573               0                0           -1
# 901360          2829               0                0           -1
# 776546          2829               0                0           -1
# 902741          2836               0                0           -1
# 390130          2598               0                0           -1
# 180035          3842               0                0           -1
# 595917          2870               0                0           -1
# ...              ...             ...              ...          ...
# 1352064         2435               1                0          320
# 1352065         2443               0                0           -1
# 1352066         2393               0                0           -1
# 1352068         2295               0                0           -1
# 1352058         2341               0                0           -1
# 1352069         2330               0                0           -1
# 1352070         2299               0                0           -1
# 1352071         2318               0                0           -1
# 1352072         2331               0                0           -1
# 1352073         2276               0                0           -1
# 1352075         2482               0                0           -1
# 1352059         2346               0                0           -1
# 1352057         2499               0                0           -1
# 1352040         2439               0                0           -1
# 1352048         2394               0                0           -1
# 1352041         2404               0                0           -1
# 1352042         2411               0                0           -1
# 1352043         2435               0                0           -1
# 1352045         2362               0                0           -1
# 1352046         2371               0                0           -1
# 1352047         2380               0                0           -1
# 1352049         2304               0                0           -1
# 1352056         2484               0                0           -1
# 1352050         2186               0                0           -1
# 1352051         2200               0                0           -1
# 1352052         2203               0                0           -1
# 1352053         2157               1                0           -1
# 1352054         2460               0                0           -1
# 1352055         2496               0                0           -1
# 3063286         2133               0                0           -1
#
#          banner_height inventory_source  inventory_interstitial     spend  \
# 128836              -1          RUBICON                       0  0.260739
# 684424              -1        STICKYADS                       0  0.211046
# 730928              -1        STICKYADS                       0  0.197464
# 430258              -1        STICKYADS                       0  0.187634
# 210806              -1            MOPUB                       0  0.131718
# 52807               -1          RUBICON                       0  0.163207
# 966954              -1           TREMOR                       1  0.127330
# 205230              -1           TREMOR                       1  0.119548
# 10773               -1           TREMOR                       1  0.117859
# 236123              -1           TREMOR                       1  0.113349
# 180741              -1           TREMOR                       1  0.113370
# 1037096             -1           TREMOR                       1  0.109953
# 20392               -1           TREMOR                       1  0.108938
# 48081               -1           TREMOR                       1  0.110691
# 265941              -1           TREMOR                       1  0.107294
# 22575               -1           TREMOR                       1  0.107305
# 121866              -1           TREMOR                       1  0.105695
# 658156              -1           TREMOR                       1  0.103286
# 735232              -1          RUBICON                       0  0.131702
# 182478              -1           TREMOR                       1  0.108053
# 96144               -1           TREMOR                       1  0.106576
# 201842              -1           TREMOR                       1  0.107925
# 359047              -1           TREMOR                       1  0.101264
# 587928              -1           TREMOR                       1  0.101264
# 901360              -1           TREMOR                       1  0.101264
# 776546              -1           TREMOR                       1  0.101264
# 902741              -1           TREMOR                       1  0.101264
# 390130              -1           TREMOR                       1  0.101264
# 180035              -1           TREMOR                       1  0.104768
# 595917              -1           TREMOR                       1  0.101264
# ...                ...              ...                     ...       ...
# 1352064            480            MOPUB                       1  0.003226
# 1352065             -1          RUBICON                       1  0.003483
# 1352066             -1          RUBICON                       0  0.003799
# 1352068             -1          RUBICON                       0  0.003746
# 1352058             -1          RUBICON                       0  0.003771
# 1352069             -1          RUBICON                       0  0.003543
# 1352070             -1           TREMOR                       1  0.003017
# 1352071             -1          RUBICON                       0  0.003543
# 1352072             -1        STICKYADS                       0  0.003677
# 1352073             -1          RUBICON                       0  0.003721
# 1352075             -1        STICKYADS                       0  0.003799
# 1352059             -1        STICKYADS                       0  0.003799
# 1352057             -1        STICKYADS                       0  0.003799
# 1352040             -1        STICKYADS                       0  0.002687
# 1352048             -1        STICKYADS                       0  0.003677
# 1352041             -1        STICKYADS                       0  0.003799
# 1352042             -1          RUBICON                       1  0.003799
# 1352043             -1          RUBICON                       0  0.003746
# 1352045             -1          RUBICON                       0  0.003796
# 1352046             -1        STICKYADS                       0  0.002687
# 1352047             -1        STICKYADS                       0  0.002687
# 1352049             -1        STICKYADS                       0  0.003799
# 1352056             -1          RUBICON                       0  0.003799
# 1352050             -1        STICKYADS                       0  0.002687
# 1352051             -1          RUBICON                       0  0.003698
# 1352052             -1          RUBICON                       0  0.003799
# 1352053             -1          RUBICON                       1  0.002825
# 1352054             -1          RUBICON                       0  0.003783
# 1352055             -1        STICKYADS                       0  0.002687
# 3063286             -1        STICKYADS                       0  0.002687
#
#             score
# 128836   0.132886
# 684424   0.963134
# 730928   0.972592
# 430258   0.972592
# 210806   0.309836
# 52807    0.998319
# 966954   0.210607
# 205230   0.301654
# 10773    0.475198
# 236123   0.114248
# 180741   0.224240
# 1037096  0.148184
# 20392    0.107937
# 48081    0.401911
# 265941   0.143286
# 22575    0.316149
# 121866   0.585413
# 658156   0.496535
# 735232   0.622300
# 182478   0.263666
# 96144    0.398529
# 201842   0.250065
# 359047   0.581363
# 587928   0.202112
# 901360   0.224966
# 776546   0.422280
# 902741   0.522531
# 390130   0.344135
# 180035   0.120940
# 595917   0.504472
# ...           ...
# 1352064  0.011023
# 1352065  0.001913
# 1352066  0.007669
# 1352068  0.007025
# 1352058  0.000971
# 1352069  0.006689
# 1352070  0.000441
# 1352071  0.003446
# 1352072  0.001347
# 1352073  0.000335
# 1352075  0.089293
# 1352059  0.234969
# 1352057  0.074525
# 1352040  0.011341
# 1352048  0.002943
# 1352041  0.228465
# 1352042  0.160594
# 1352043  0.014073
# 1352045  0.013449
# 1352046  0.018145
# 1352047  0.030984
# 1352049  0.111734
# 1352056  0.007360
# 1352050  0.019094
# 1352051  0.000504
# 1352052  0.000168
# 1352053  0.006235
# 1352054  0.004002
# 1352055  0.020315
# 3063286  0.006902
#
# [3063287 rows x 26 columns]
