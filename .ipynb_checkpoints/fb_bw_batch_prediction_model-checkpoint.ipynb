# %%
import boto3
import datetime as dt
import pytz
import time
import uuid
import json
import s3fs
from urllib.parse import urlparse
import pandas as pd
import requests
import numpy as np
from decimal import *
from io import StringIO
import numpy as np

# %%
cookies = {
}

data = '{"email":"btomasette@camelotsmm.com", "password":"Dunmore1"}'

auth = 'https://facebook.api.beeswax.com/rest/authenticate'

get_advertisers = 'https://facebook.api.beeswax.com/rest/advertiser'

save_report = 'https://facebook.api.beeswax.com/rest/report_save'

report_queue = 'https://facebook.api.beeswax.com/rest/report_queue'

list_item_bulk = 'https://facebook.api.beeswax.com/rest/list_item_bulk'

get_lists = 'https://facebook.api.beeswax.com/rest/custom_list'

bid_model_version = 'https://facebook.api.beeswax.com/rest/bid_model_version'

update_active_model_version = 'https://facebook.api.beeswax.com/rest/bid_model/strict/1' 

r = requests.post(auth, cookies=cookies, data=data)

tz = pytz.timezone('EST')

today = dt.datetime.now(tz)
sevenday = today - dt.timedelta(days=7)

# %%
# query athena view of impression, click, and joined conversion data for tag_id 3
query = """
SELECT  conversions,
         campaign_id,
         impressions,
         clicks,
         app_bundle,
         ad_position,
         geo_region,
         geo_country,
         platform_browser,
         platform_os,
         rewarded,
         platform_carrier,
         platform_device_make,
         platform_device_model,
         video_player_size,
         video_completes,
         content_language,
         companion_views,
         companion_clicks,
         banner_width,
         banner_height,
         inventory_source,
         inventory_interstitial,
         spend
FROM "fb-prod"."fbbatchprediction" 
"""

# %%
# set database to facebook
database = 'fb-prod'
#set s3 output file for athena query
s3_output = 's3://fb-beeswax/brian/athena/%s/'%(dt.datetime.now(tz).strftime('%Y-%m-%d-%H%M%S'))

#Function for starting athena query
def run_query(query, database, s3_output):
    client = boto3.client('athena', region_name='us-east-1')
    response = client.start_query_execution(
        QueryString=query,
        QueryExecutionContext={
            'Database': database
            },
        ResultConfiguration={
            'OutputLocation': s3_output,
            }
        )
    print('Execution ID: ' + response['QueryExecutionId'])
    return response

#run athena query and kick back job id
job = run_query(query, database, s3_output)

job_id = job['QueryExecutionId']
client = boto3.client('athena', region_name='us-east-1')
res = client.get_query_execution(QueryExecutionId= job_id)
x = 0

# wait for athena to return results
while res['QueryExecution']['Status']['State'] != 'SUCCEEDED':
    print("it's been {} seconds".format(str(x)))
    time.sleep(10)
    x = x + 10
    res = client.get_query_execution(QueryExecutionId= job_id)

#set output location for query results
output = res['QueryExecution']['ResultConfiguration']['OutputLocation']
# Out:
# Execution ID: 298b4031-d1c1-4f49-a039-49024de959fa
# it's been 0 seconds
# it's been 10 seconds
# it's been 20 seconds

# %%
#set aws machine learning client and build schema for datasource
mlclient = boto3.client('machinelearning', region_name='us-east-1')

data_id = str(uuid.uuid4())
data_name = 'fb-datasource-%s'%(dt.datetime.now(tz).strftime('%Y-%m-%d-%H%M%S'))

schema = {
        'excludedAttributeNames': [], 
        'version': '1.0', 
        'dataFormat': 'CSV', 
        'rowId': None, 
        'dataFileContainsHeader': True, 
        'attributes': [
            {
                'attributeName': 'conversions', 
                'attributeType': 'BINARY'
            }, {
                'attributeName' : 'campaign_id',
                'attributeType' : 'CATEGORICAL'
            }, {
                'attributeName': 'impressions', 
                'attributeType': 'NUMERIC'
            }, {
                'attributeName': 'clicks', 
                'attributeType': 'NUMERIC'
            }, {
                'attributeName': 'app_bundle', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'ad_position', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'geo_region', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'geo_country', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'platform_browser', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'platform_os', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'rewarded', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'platform_carrier', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'platform_device_make', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'platform_device_model', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'video_player_size', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'video_completes', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'content_language', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'companion_views', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'companion_clicks', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'banner_width', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'banner_height', 
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'inventory_source',
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'inventory_interstitial',
                'attributeType': 'CATEGORICAL'
            }, {
                'attributeName': 'spend',
                'attributeType': 'NUMERIC'
            }
        ]
    }


# load new datasource into aws machine learning
response = mlclient.create_data_source_from_s3(DataSourceId=data_id, DataSourceName=data_name, DataSpec={"DataLocationS3" : output, "DataSchema" : json.dumps(schema)}, ComputeStatistics=True)

# %%
#build new batch prediction and set output file in S3
prediction_id = str(uuid.uuid4())
prediction_name = 'fb-prediction-%s'%(dt.datetime.now(tz).strftime('%Y-%m-%d-%H%M%S'))
prediction_output = 's3://fb-beeswax/brian/ml/%s/'%(dt.datetime.now(tz).strftime('%Y-%m-%d-%H%M%S'))
prediction_data_source_id = response['DataSourceId']
pred = mlclient.create_batch_prediction(BatchPredictionId=prediction_id, BatchPredictionName=prediction_name, MLModelId='0ce4ba6e-acd9-4209-a725-013a6262ecce', BatchPredictionDataSourceId=prediction_data_source_id , OutputUri=prediction_output)

get_pred = mlclient.get_batch_prediction(BatchPredictionId=pred['BatchPredictionId'])
gpt = 0
while get_pred['Status'] != 'COMPLETED':
    time.sleep(30)
    gpt = gpt + 30
    print("batch prediction processing for %s seconds" %gpt)
    get_pred = mlclient.get_batch_prediction(BatchPredictionId=pred['BatchPredictionId'])
# Out:
# batch prediction processing for 30 seconds
# batch prediction processing for 60 seconds
# batch prediction processing for 90 seconds
# batch prediction processing for 120 seconds
# batch prediction processing for 150 seconds
# batch prediction processing for 180 seconds
# batch prediction processing for 210 seconds

# %%
#load original athena result into a dataframe
df = pd.read_csv(output)

#build score output url
o = urlparse(output)
score = get_pred['OutputUri'] + 'batch-prediction/result/' + get_pred['BatchPredictionId'] + '-' + o[2].split('/')[4].split('.')[0] + '.csv.gz'

#load score into a dataframe
ds = pd.read_csv(score, compression='gzip')

df['score'] = ds['score']

# %%
#calculate range of scores
#range = df['score'].max() - df['score'].min()

#zero out any items below 0.009

#df['bid_mod'] = df['score'].apply(lambda y : 0 if y < 0.01 else y)

s3 = boto3.client(
    's3', region_name='us-east-1')
csv_buffer = StringIO()
df.to_csv(csv_buffer, index=False)
res = s3.put_object(Body = csv_buffer.getvalue(),
                               ContentType='text/csv',
                               Bucket='fb-beeswax',
                               Key = 'brian/ml-prediction/{}/{}.csv'.format(dt.datetime.now(tz).strftime('%Y-%m-%d'), prediction_name ))

# %%
ds.head()
# Out:
#    bestAnswer     score
# 0           0  0.002483
# 1           0  0.013838
# 2           0  0.018301
# 3           0  0.000216
# 4           0  0.000031

# %%
df.head()
# Out:
#    conversions  campaign_id  impressions  clicks                  app_bundle  \
# 0            0            6            1       0         com.weather.weather
# 1            0            6            1       0         com.weather.weather
# 2            0            6            1       0         com.weather.weather
# 3            0            6            1       0         com.weather.Weather
# 4            0            6            1       0  com.mobilityware.solitaire
#
#         ad_position geo_region geo_country platform_browser platform_os  \
# 0  POSITION_UNKNOWN     USA/WI         USA    Chrome Mobile     Android
# 1  POSITION_UNKNOWN     USA/TN         USA    Chrome Mobile     Android
# 2  POSITION_UNKNOWN     USA/OH         USA    Chrome Mobile     Android
# 3  POSITION_UNKNOWN     USA/OR         USA    Chrome Mobile     Android
# 4               NaN     USA/IN         USA    Chrome Mobile     Android
#
#      ...     video_completes content_language companion_views  \
# 0    ...                   1               en               1
# 1    ...                   1               en               1
# 2    ...                   1               en               1
# 3    ...                   1               EN               0
# 4    ...                   0              NaN               0
#
#   companion_clicks banner_width  banner_height inventory_source  \
# 0                0           -1             -1          RUBICON
# 1                0           -1             -1          RUBICON
# 2                0           -1             -1          RUBICON
# 3                0           -1             -1          RUBICON
# 4                0           -1             -1             LKQD
#
#    inventory_interstitial     spend     score
# 0                       0  0.003933  0.002483
# 1                       0  0.003745  0.013838
# 2                       0  0.004121  0.018301
# 3                       0  0.004144  0.000216
# 4                       0  0.004291  0.000031
#
# [5 rows x 25 columns]

# %%
dz = df.drop(['conversions', 'video_completes', 'impressions', 'clicks', 'companion_views', 'companion_clicks', 'spend'], axis=1)

# %%
cols = ['banner_width', 'banner_height', 'rewarded']
for col in cols:
   dz[col] = df[col].apply(lambda x: int(x) if x == x else "")

# %%
dz.head(16)
# Out:
#     campaign_id                           app_bundle       ad_position  \
# 0             6                  com.weather.weather  POSITION_UNKNOWN
# 1             6                  com.weather.weather  POSITION_UNKNOWN
# 2             6                  com.weather.weather  POSITION_UNKNOWN
# 3             6                  com.weather.Weather  POSITION_UNKNOWN
# 4             6           com.mobilityware.solitaire               NaN
# 5             6             com.myfitnesspal.android  POSITION_UNKNOWN
# 6             6                  com.weather.weather  POSITION_UNKNOWN
# 7             6             com.myfitnesspal.android               NaN
# 8             6             com.myfitnesspal.android               NaN
# 9             6                     com.zynga.words3  POSITION_UNKNOWN
# 10            6                     com.zynga.words3  POSITION_UNKNOWN
# 11            6                     com.myyearbook.m  POSITION_UNKNOWN
# 12            6  com.pixel.art.coloring.color.number  POSITION_UNKNOWN
# 13            6      com.zynga.crosswordswithfriends  POSITION_UNKNOWN
# 14            6                       com.ea.gp.bej3               NaN
# 15            6      com.zynga.crosswordswithfriends  POSITION_UNKNOWN
#
#    geo_region geo_country platform_browser platform_os  rewarded  \
# 0      USA/WI         USA    Chrome Mobile     Android        -1
# 1      USA/TN         USA    Chrome Mobile     Android        -1
# 2      USA/OH         USA    Chrome Mobile     Android        -1
# 3      USA/OR         USA    Chrome Mobile     Android        -1
# 4      USA/IN         USA    Chrome Mobile     Android        -1
# 5      USA/FL         USA    Chrome Mobile     Android        -1
# 6      USA/NY         USA    Chrome Mobile     Android        -1
# 7      USA/DC         USA    Chrome Mobile     Android        -1
# 8      USA/MI         USA    Chrome Mobile     Android        -1
# 9      USA/IL         USA    Chrome Mobile     Android        -1
# 10     USA/GA         USA    Chrome Mobile     Android        -1
# 11     USA/UT         USA    Chrome Mobile     Android        -1
# 12     USA/GA         USA    Chrome Mobile     Android        -1
# 13     USA/IL         USA    Chrome Mobile     Android        -1
# 14     USA/GA         USA    Chrome Mobile     Android        -1
# 15     USA/IL         USA    Chrome Mobile     Android        -1
#
#    platform_carrier platform_device_make platform_device_model  \
# 0               NaN              Samsung              SM-J120G
# 1               NaN              Samsung             SM-G550FY
# 2               NaN              Samsung              SM-A730F
# 3               NaN             Motorola                XT1650
# 4               NaN              Samsung              SM-G950U
# 5               NaN              Samsung              SM-G955U
# 6           Verizon               Huawei               RNE-L22
# 7               NaN             Motorola          Moto G6 Play
# 8           Verizon             Motorola                XT1254
# 9               NaN              Samsung              SM-J530Y
# 10              NaN              Samsung              SM-G935F
# 11              NaN              Samsung             SM-S727VL
# 12              NaN              Samsung              SM-G5700
# 13              NaN              Samsung              SM-G935F
# 14              NaN              Samsung              SM-G928V
# 15         T-Mobile                   LG                 LS997
#
#    video_player_size content_language  banner_width  banner_height  \
# 0                  M               en            -1             -1
# 1                  M               en            -1             -1
# 2                  M               en            -1             -1
# 3                NaN               EN            -1             -1
# 4                  M              NaN            -1             -1
# 5                  M              NaN            -1             -1
# 6                  M               en            -1             -1
# 7                  L              NaN            -1             -1
# 8                  M              NaN            -1             -1
# 9                  M               en            -1             -1
# 10                 M               en            -1             -1
# 11                 L               en            -1             -1
# 12                 M               en            -1             -1
# 13                 M               en            -1             -1
# 14                 L              NaN            -1             -1
# 15                 M               en            -1             -1
#
#    inventory_source  inventory_interstitial     score
# 0           RUBICON                       0  0.002483
# 1           RUBICON                       0  0.013838
# 2           RUBICON                       0  0.018301
# 3           RUBICON                       0  0.000216
# 4              LKQD                       0  0.000031
# 5            SMAATO                       0  0.002137
# 6           RUBICON                       0  0.017562
# 7              LKQD                       0  0.002283
# 8              LKQD                       0  0.004756
# 9           RUBICON                       0  0.000564
# 10          RUBICON                       0  0.000602
# 11          RUBICON                       0  0.093816
# 12          RUBICON                       0  0.807286
# 13          RUBICON                       0  0.006214
# 14       PULSEPOINT                       0  0.063443
# 15          RUBICON                       0  0.012049

# %%
dz.rename(columns={'score':'value'}, inplace=True)

# %%
dz.replace(-1, "", inplace=True)

# %%
dz.replace({'ad_position' : {'0' : np.nan}}, inplace=True)

# %%
dz.head()
# Out:
#    campaign_id                  app_bundle       ad_position geo_region  \
# 0            6         com.weather.weather  POSITION_UNKNOWN     USA/WI
# 1            6         com.weather.weather  POSITION_UNKNOWN     USA/TN
# 2            6         com.weather.weather  POSITION_UNKNOWN     USA/OH
# 3            6         com.weather.Weather  POSITION_UNKNOWN     USA/OR
# 4            6  com.mobilityware.solitaire               NaN     USA/IN
#
#   geo_country platform_browser platform_os rewarded platform_carrier  \
# 0         USA    Chrome Mobile     Android                       NaN
# 1         USA    Chrome Mobile     Android                       NaN
# 2         USA    Chrome Mobile     Android                       NaN
# 3         USA    Chrome Mobile     Android                       NaN
# 4         USA    Chrome Mobile     Android                       NaN
#
#   platform_device_make platform_device_model video_player_size  \
# 0              Samsung              SM-J120G                 M
# 1              Samsung             SM-G550FY                 M
# 2              Samsung              SM-A730F                 M
# 3             Motorola                XT1650               NaN
# 4              Samsung              SM-G950U                 M
#
#   content_language banner_width banner_height inventory_source  \
# 0               en                                     RUBICON
# 1               en                                     RUBICON
# 2               en                                     RUBICON
# 3               EN                                     RUBICON
# 4              NaN                                        LKQD
#
#    inventory_interstitial     value
# 0                       0  0.002483
# 1                       0  0.013838
# 2                       0  0.018301
# 3                       0  0.000216
# 4                       0  0.000031

# %%
file_size = dz.memory_usage(index=True).sum()
partitions = round(file_size/1024/1024/10)

# %%
s3 = boto3.client(
    's3', aws_access_key_id='AKIAJKXTYAFKSXDNEWKQ',
    aws_secret_access_key='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', region_name='us-east-1')
s3resource = boto3.resource('s3', aws_access_key_id='AKIAJKXTYAFKSXDNEWKQ',
    aws_secret_access_key='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', region_name='us-east-1')

# %%
number_of_chunks = partitions
s3_array = []
for id, dz_i in  enumerate(np.array_split(dz, number_of_chunks)):
    csv_buffer = StringIO()
    dz_i.to_csv(csv_buffer, sep='|', index=False)
    bucket = 'beeswax-data-us-east-1'
    prefix = 'bid_models/facebook/predictions/'
    key = '{}_{}_file{id}.csv'.format(dt.datetime.now(tz).strftime('%Y-%m-%d'), prediction_name, id=id )
    res = s3.put_object(Body = csv_buffer.getvalue(),
                               ContentType='text/csv',
                               Bucket= bucket,
                               Key = prefix + key)
    s3resource.Object(bucket, prefix+key).Acl().put(ACL='bucket-owner-full-control')
    s3_array.append('s3://{}/{}{}'.format(bucket, prefix, key))

# %%
s3_array
# Out:
# ['s3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file0.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file1.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file2.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file3.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file4.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file5.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file6.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file7.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file8.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file9.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file10.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file11.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file12.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file13.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file14.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file15.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file16.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file17.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file18.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file19.csv',
#  's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file20.csv']

# %%
print(key)
print(prefix+key)
print(res)
# Out:
# 2019-02-27_fb-prediction-2019-02-27-220921_file20.csv
# bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file20.csv
# {'ResponseMetadata': {'RequestId': '0EB813F7E87C67B4', 'HostId': 'YRWQJFO+DrnKHLnsKRiJb+8kyFV1xRChNtaYuKNX8TvzkWqCIezLwNb5DIpW/6O6IKn7UykgXHU=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'YRWQJFO+DrnKHLnsKRiJb+8kyFV1xRChNtaYuKNX8TvzkWqCIezLwNb5DIpW/6O6IKn7UykgXHU=', 'x-amz-request-id': '0EB813F7E87C67B4', 'date': 'Thu, 28 Feb 2019 03:22:28 GMT', 'x-amz-version-id': 'q2dp6xmAMSQCou1_w8U1QmJ56ENctIvK', 'etag': '"db7401a99f4a41e6a1192af87871d437"', 'content-length': '0', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ETag': '"db7401a99f4a41e6a1192af87871d437"', 'VersionId': 'q2dp6xmAMSQCou1_w8U1QmJ56ENctIvK'}

# %%
dmanifest = dz.drop(['value'], axis=1)

# %%
manifest = {
    'model_predictions' : 
        s3_array
    ,
    'metadata' : {
        'fields' : dmanifest.columns.tolist()
    }
}

# %%
print(manifest)
# Out:
# {'model_predictions': ['s3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file0.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file1.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file2.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file3.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file4.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file5.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file6.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file7.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file8.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file9.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file10.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file11.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file12.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file13.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file14.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file15.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file16.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file17.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file18.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file19.csv', 's3://beeswax-data-us-east-1/bid_models/facebook/predictions/2019-02-27_fb-prediction-2019-02-27-220921_file20.csv'], 'metadata': {'fields': ['campaign_id', 'app_bundle', 'ad_position', 'geo_region', 'geo_country', 'platform_browser', 'platform_os', 'rewarded', 'platform_carrier', 'platform_device_make', 'platform_device_model', 'video_player_size', 'content_language', 'banner_width', 'banner_height', 'inventory_source', 'inventory_interstitial']}}

# %%
obj_manifest = s3resource.Object(bucket,'bid_models/facebook/customer_manifests/manifest_{}.json'.format(key))
obj_manifest.put(Body=json.dumps(manifest))
obj_manifest.Acl().put(ACL='bucket-owner-full-control')
# Out:
# {'ResponseMetadata': {'RequestId': '3AC47F4016C0F7C7',
#   'HostId': '7dWB6TSvDK7BG3VpqW7rkqtij7dM0xTMn1RVV1xtxNER3sQmbUNcII8s6TF1PXODD96faqHk7PA=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '7dWB6TSvDK7BG3VpqW7rkqtij7dM0xTMn1RVV1xtxNER3sQmbUNcII8s6TF1PXODD96faqHk7PA=',
#    'x-amz-request-id': '3AC47F4016C0F7C7',
#    'date': 'Thu, 28 Feb 2019 03:24:21 GMT',
#    'x-amz-version-id': '.saPZGMz..wK6N1U3iq2ho..lO.W3oEX',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0}}

# %%
manifest_path = 's3://{}/{}'.format(bucket, 'bid_models/facebook/customer_manifests/manifest_{}.json'.format(key))

# %%
manifest_path
# Out:
# 's3://beeswax-data-us-east-1/bid_models/facebook/customer_manifests/manifest_2019-02-27_fb-prediction-2019-02-27-220921_file20.csv.json'

# %%
model = {
    "active" : True,
    "bid_model_id" : 1,
    "bid_model_version_name" : '{}_{}'.format(dt.datetime.now(tz).strftime('%Y-%m-%d-%H%M%S'), prediction_name ),
    "manifest_s3_path" : manifest_path
}

# %%
model
# Out:
# {'active': True,
#  'bid_model_id': 1,
#  'bid_model_version_name': '2019-02-27-222517_fb-prediction-2019-02-27-220921',
#  'manifest_s3_path': 's3://beeswax-data-us-east-1/bid_models/facebook/customer_manifests/manifest_2019-02-27_fb-prediction-2019-02-27-220921_file20.csv.json'}

# %%
upload_model = requests.post(bid_model_version, cookies=r.cookies, data=json.dumps(model))

# %%
upload_model.json()
# Out:
# {'success': True,
#  'payload': {'id': 11},
#  'message': 'bid_model_version created with ID = 11'}

# %%
model_version_data = {
    "bid_model_id" : 1,
    "active" : True,
    "current_version" : upload_model.json()['payload']['id']
}

# %%
update_version = requests.put(update_active_model_version, cookies=r.cookies, data=json.dumps(model_version_data))

# %%
update_version.json()
# Out:
# {'success': True,
#  'payload': [{'id': 1,
#    'success': True,
#    'message': 'bid_model updated with ID 1'}],
#  'message': 'bid_model update: 1 updated successfully'}
